# %% [markdown]
# # Laboratorio 11
# ## Solve  Problem A – Ehab and another construction problem
# ### Nicolas David Contreras Ramirez
# Resuelva el problema A: Ehab y otro problema de construcción   de la búsqueda completa en Vjudge y en Colab

# %%
def ent(a):
    for i in range(1,a+1):
        j = a
        while(j!=1):
            if(j%i==0):
                if(i*j>a and j/i<a):
                    print(j,i)
                    return
                break;
            j=j-1
    print(-1)
a = int(input())
ent(a)
# Out:
#  10
# 10 2

# %% [markdown]
# ![image.png](attachment:d8c41dd7-29a4-4932-ac50-44242ef39900.png)

# %% [markdown]
# ![image.png](attachment:a66ecf1b-ada1-4928-bb2d-1cdf5746fbe2.png)

# %% [markdown]
# ![image.png](attachment:d1df72fb-7027-424c-a92d-27d46481975a.png)

# %%
a = int(input())
if(a!=1):
    if(a%2==0):
        print(a,"",2)
    else:
        print(a-1,"",2)
else:
    print(-1)
# Out:
#  10
# 10  2

# %% [markdown]
# ![image.png](attachment:b53815f5-f683-4cda-a910-73b4bfa33397.png)

# %%
x = int(input())
if(x!=1):
    print(x,"",x)
else:
    print(-1)

# %% [markdown]
# ![image.png](attachment:aee1e036-fa53-41fe-952b-ff6de553e2f0.png)

# %% [markdown]
# # Resultado de las operaciones

# %% [markdown]
# ![image.png](attachment:526fcf73-ca0c-4bd8-9e7e-da7497cbf3d5.png)

# %% [markdown]
# ![image.png](attachment:52d389bf-ad7d-4ac2-ae88-47089334795f.png)
